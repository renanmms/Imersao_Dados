# %% [markdown]
# ## Aula 01
#
# ### Python, Pandas e Pharmacia

# %%
10 + 11
# Out:
# 21

# %%
"Renan"
# Out:
# 'Renan'

# %%
import pandas as pd
# que tipo de informação eu estou trabalhando
# Células cultivadas em micro-placa
url_dados = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"
dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 877 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados["tratamento"]
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique() # controle da variável e ver o 'efeitos' delas
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
import matplotlib.pyplot as plt

dados["tempo"].unique()
x = dados["tempo"].value_counts()

plt.hist(x)
# Out:
# (array([2., 0., 0., 0., 0., 0., 0., 0., 0., 1.]),
#  array([7772. , 7819.8, 7867.6, 7915.4, 7963.2, 8011. , 8058.8, 8106.6,
#         8154.4, 8202.2, 8250. ]),
#  <a list of 10 Patch objects>)

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados["droga"].unique() # tem várias informações
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados["g-1"].unique() # g-1 são as expressões gênicas
# Out:
# array([ 0.5577,  0.4087,  0.5817, ..., -0.8037, -0.3696, -0.0636])

# %%
# freq. de valores
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['c-0']
# Out:
# 0       -0.0600
# 1        0.0927
# 2       -0.1312
# 3       -0.3998
# 4       -0.3774
#           ...
# 23809    0.4224
# 23810    0.2144
# 23811    1.0650
# 23812    0.5377
# 23813   -2.3890
# Name: c-0, Length: 23814, dtype: float64

# %%
# Desafio 04  
qtd_drogas = dados['droga'].value_counts()
len(qtd_drogas) - 1
# Out:
# 3288

# %%
dados['tempo'].value_counts().plot.bar() # o histograma traz mais informações do que o gráfico pizza

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
dados[dados['g-0'] > 0] # filtro
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
#
# [11769 rows x 877 columns]

# %%
mapa = {"droga" : "composto"}
dados.rename(columns=mapa, inplace=True)

# %%
cod_compostos = dados['composto'].value_counts().index[:5]

cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
#
# [3235 rows x 877 columns]

# %% [markdown]
# ## Aula 02
#
# ### Estatísticas, visualização de dados e distribuições

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
#
plt.figure(figsize = (10, 8))
ax = sns.countplot(x = 'composto',  data=dados.query('composto in @cod_compostos')) # a query procura as linhas que possui dados no conj. de cod_compostos
ax.set_title('Top 5 Compostos')
plt.show()

# %%
len(dados['g-0'].unique())
# Out:
# 14367

# %%
dados['g-0'].min()
# Out:
# -5.513

# %%
dados['g-0'].max()
# Out:
# 10.0

# %%
# Plotando o histograma
dados['g-0'].hist(bins = 100) # quanto maior o bins mais parecido com uma curva normal

# %%
dados['g-19'].hist(bins = 100)

# %%
dados['g-0'].mean()
# Out:
# 0.24836629293692816

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g-0', 'g-1']]
# Out:
#           g-0     g-1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[0,'g-0']
# Out:
# 1.062

# %%
dados.loc[:, 'g-0':'g-771'].describe()
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[:, 'g-0':'g-771'].describe().T['min'].hist(bins=30) # Transpor matriz

# %%
dados.loc[:, 'g-0':'g-771'].describe().T['max'].hist(bins=30)

# %%
# Z Score Robusto
# clue.io
dados.loc[:, 'c-0':'c-99'].describe().T['mean'].hist(bins=25)

# %%
# Os c's são tipos de celulas
sns.boxplot(x= "g-0", data=dados) # Distribuição dos valores
# Outliers são pontos 'soltos' que fogem do padrão

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(y= "g-0", x = 'tratamento', data=dados)

# %% [markdown]
# ## Aula 03
#
# ### Correlações, causalidade e relações entre genes

# %%
# Tabela de Frequencia
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados["tratamento"])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados["tratamento"], normalize='index') # Calcula a proporção
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
# Calcular media da freq. dos valores de g-0
pd.crosstab([dados['dose'], dados['tempo']], dados["tratamento"], values=dados['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
expr_gen = dados[['g-0', 'g-3']]

# %%
sns.scatterplot(x = 'g-0', y = 'g-3', data=dados)

# %%
sns.scatterplot(x = 'g-0', y = 'g-8', data=dados)

# %%
sns.set_theme(color_codes=True)
sns.lmplot( x='g-0', y='g-8', data=dados, line_kws={"color" : "green"})

# %%
sns.lmplot( x='g-0', y='g-8', data=dados, line_kws={"color" : "red"}, col='tratamento')

# %%
sns.lmplot( x='g-0', y='g-8', data=dados, line_kws={"color" : "green"}, col='tratamento', row='tempo')

# %%
x = dados.loc[:, 'g-0' : 'g-50'].corr()
corr_celular = dados.loc[:, 'c-0' : 'c-50'].corr()

# %%
import numpy as np
# Compute the correlation matrix
corr = x

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## Aula 04
#
# ### Merge de dados e análise de resultados

# %%
dados_resultados = pd.read_csv("https://github.com/alura-cursos/imersao-dados-desafio-final/blob/main/Dados/dados_resultados.csv?raw=true")
dados_resultados.head().T # Tranpondo a tabela
# Out:
#                                                   0  ...             4
# id                                     id_000644bb2  ...  id_001626bd3
# 5-alpha_reductase_inhibitor                       0  ...             0
# 11-beta-hsd1_inhibitor                            0  ...             0
# acat_inhibitor                                    0  ...             0
# acetylcholine_receptor_agonist                    0  ...             0
# ...                                             ...  ...           ...
# ubiquitin_specific_protease_inhibitor             0  ...             0
# vegfr_inhibitor                                   0  ...             0
# vitamin_b                                         0  ...             0
# vitamin_d_receptor_agonist                        0  ...             0
# wnt_inhibitor                                     0  ...             0
#
# [207 rows x 5 columns]

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
contagem_moa = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False) # A coluna inteira precisa ser um valor númerico
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.sum() # aqui ele tá concatenando a coluna id
# Out:
# id                                       id_000644bb2id_000779bfcid_000a6266aid_0015fd3...
# 5-alpha_reductase_inhibitor                                                             17
# 11-beta-hsd1_inhibitor                                                                  18
# acat_inhibitor                                                                          24
# acetylcholine_receptor_agonist                                                         190
#                                                                ...
# ubiquitin_specific_protease_inhibitor                                                    6
# vegfr_inhibitor                                                                        170
# vitamin_b                                                                               26
# vitamin_d_receptor_agonist                                                              39
# wnt_inhibitor                                                                           30
# Length: 207, dtype: object

# %%
d =  dados_resultados.drop('id', axis=1).sum() # valores não ordenados

# %%
d.sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7808ab2f717f> in <module>()
# ----> 1 d.sort_values(ascending=False)
#
# NameError: name 'd' is not defined

# %%
dados_resultados.drop('id', axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1) # 
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id', 'n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"' )['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
 dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts() # conta a freq. de valores de cada tipo no df 
 dados_combinados['composto']
# Out:
# 0        b68db1d53
# 1        df89a8e5a
# 2        18bb41b2c
# 3        8c7f86626
# 4        7cbed3131
#            ...
# 23809    df1d0a5a1
# 23810    ecf3b6b74
# 23811    cacb2b860
# 23812    8b87a7a83
# 23813    972f41291
# Name: composto, Length: 23814, dtype: object

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(14, 8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y='g-0', x='composto', hue='ativo_moa')

# %% [markdown]
# ## Aula 05
#
# ### Machine Learning, Sci-kit learning e desafios envolvidos.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split # para separar um conjunto de dados


x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state = 376)

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)
# verificar a qualidade do modelo
modelo_rlogistica.score(x_teste, y_teste)

# 0.6365 acertou 63% das previsões
# Out:
# 0.6267058576527399

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state = 376)


modelo_arvore = DecisionTreeClassifier(max_depth = 7) # qto maior a profundida maior a acurácia do classificador da árvore de decisão
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.6210371614528658

# %%
from sklearn.tree import DecisionTreeClassifier
 
x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state = 376)

teste = []
treino = []
for i in range(1, 15): # roda 14 arvores de decisão
  modelo_arvore = DecisionTreeClassifier(max_depth = i)
  modelo_arvore.fit(x_treino, y_treino)
  teste.append(modelo_arvore.score(x_teste, y_teste))
  treino.append(modelo_arvore.score(x_treino, y_treino))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6206172580306529,
#  0.6212471131639723,
#  0.6183077892084821,
#  0.6204073063195465,
#  0.6204073063195465,
#  0.6172580306529498,
#  0.6136888515641402,
#  0.6092798656309049,
#  0.5966827629645182,
#  0.5981524249422633,
#  0.5987822800755827]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615,
#  0.6412261823526324,
#  0.6489423127394888,
#  0.6605427536612252,
#  0.6707259461445594,
#  0.6895176106241142,
#  0.7068395359823632,
#  0.7293580389480867,
#  0.7529788462547897,
#  0.7767571256102042,
#  0.7991706472101202]

# %%
# Visualização do Overfitting
sns.lineplot(x=range(1,15), y = teste, label='teste')
sns.lineplot(x=range(1,15), y = treino, label='treino')

# %%
pd.get_dummies(dados_combinados['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
pd.get_dummies(dados_combinados, columns=['tratamento', 'dose', 'tempo'])

# %%
dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
# Out:
#                  id   composto     g-0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 883 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state = 376)


modelo_randomforest = RandomForestClassifier() # qto maior a profundida maior a acurácia do classificador da árvore de decisão
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.6783539785849255

# %% [markdown]
# ##Desafios
#
# #### **Aula 01**
#
# #### Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?
#
# #### Desafio 02: Plotar as 5 últimas linhas da tabela
# > dados.tail()
# #### Desafio 03: Proporção das classes tratamento.
# > dados['tratamento'].value_counts()
#
# #### Desafio 04: Quantas tipos de drogas foram investigados?
# > qtd_drogas = dados['droga'].value_counts()
#
# > len(qtd_drogas) - 1
#
# #### Desafio 05: Procurar na documentação o método query(pandas)
#
# #### Desafio 06: Renomear as colunas tirando o hífen.
#
# #### Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)
#
# #### Desafio 08: Resumo do que você aprendeu
#
# ####**Aula 2**
#
# ####Desafio 01: Ordenar o gráfico pyplot
#
# ####Desafio 02: Melhorar a visualização alterando tamanho da fonte.
#
# ####Desafio 03: Plotar os histogramas com seaborn
#
# ###Desafio 04: Estudar sobre as estatísticas no .describe()
#
# ####Desafio 05: Refletir sobre a manipulação dos tamanhos das visualizações.
#
# ####Desafio 06: Fazer outras análises com o boxplot e até com o histograma.
#
# ####Desafio 07: Resumo do que você aprendeu
# Biblioteca para plotar gráficos
# > sns.seaborn()
#
# Biblioteca matplotlib
# > plt.hist()
#
#
# ####**Aula 3**
#
# ###Desafio 01: Criar tabelas de freq. com o pandas.groupby()
#
# ###Desafio 02: Normalizar o crosstab pela coluna
#
# ###Desafio 03: Explorar outros agregadores
#
# ###Desafio 04: Explorar o melt.
#
# ###Desafio 05: Calcular e analisar a correlação entre G e C. Após isso, refletir sobre os efeitos biológicos.
#
# ###Desafio 06: Estudar o código  que plota a matriz de correlação (heatmap)
#
# ###Desafio 07: Resumo do que você aprendeu com os dados
# Calculo de frequencia de valores
# > pd.crosstab()
#
# Calculo da correlação
# > pd.corr()
#
# ###**Aula 04**
#
# ####Desafio 01: Encontrar o top 10, das ações do MOA (inibidor, agonista...)
#
# ####Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle
#
# ####Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72
#
#
# ####Desafio 04: Estudar sobre combinações de DF
#
# ####Desafio 05: Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (Escolher uma droga e comparar com controle)
#
# ####Desafio 06: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA (Ou um MOA diferente)
#
# ####Desafio 07: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa MOAs diferentes
#
# ####Desafio 08: Resumo do que você aprendeu com os dados
# Nesta aula aprendemos como fazer um merge das tabelas
# > dados_combinados = pd.merge(dados, dados_resultados['id', 'n_moa', 'ativo_moa])
#
# ####**Aula 05**
#
# ####Desafio 01: Tente outros modelos ou mude os parâmetros dos modelos que testamos em aula.
#
# ####Desafio 02: Estude a documentação do Sklearn
#
# ####Desafio 03: Pesquisar o fluxograma 'Escolhendo o melhor modelo'
# Choosing the right estimator
#
# ####Desafio 04: Testeo outros problemas (perguntas). 0, 1 ou +.
#
# ####Desafio 05: Escolha a droga mais utilizada e tente criar um modelo para prever está label.
#
# ####Desafio 06: Resumo do que você aprendeu com os dados.
#
# - Classificador por árvore de decisão
#
# - Classificador por regressão logística
